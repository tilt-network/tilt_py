# %%
import sys
import os

# Adiciona o diretório raiz do projeto (onde está a pasta tilt/)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))  # ajusta conforme sua estrutura
# ou, se você já estiver na pasta raiz:
# project_root = os.getcwd()

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from tilt.main import main
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from tilt.main import main
#
# ImportError: cannot import name 'main' from 'tilt.main' (/Users/deco/Code/tilt/tilt_py/tilt/main.py)
